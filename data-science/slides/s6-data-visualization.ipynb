# %% [markdown]
# # Session 6: data collection and visualization
# - matplotlib
# - pandas
# - pandas_datareader

# %% [markdown]
# ## Data science
#
# - [wikipedia:](https://en.wikipedia.org/wiki/Data_science)
# Data science is an inter-disciplinary field that uses scientific methods, processes, algorithms and systems to extract knowledge and insights from many structural and unstructured data. Data science is related to data mining, deep learning and big data.
#
# - data collection/mining
#   - structured
#   - unstructured
# - visualization
#   - matplotlib
# - analysis
#   - Linear regression
#   - model
# - reflection
#
#
# ### project lists
# - stocks
# - online classes and quality
# - retail
# - crime

# %% [markdown]
# ## Sample project: COVID-19 cases

# %%
# covid data
# filename: us.csv
# source: https://github.com/nytimes/covid-19-data

import pandas as pd
df=pd.read_csv('../sample-code/data/us.csv',index_col=['date'])
print(df.head())
# Out:
#             cases  deaths
# date
# 2020-01-21      1       0
# 2020-01-22      1       0
# 2020-01-23      1       0
# 2020-01-24      2       0
# 2020-01-25      3       0

# %%
df.plot()

# %%
#fig1, ax1 = plt.subplots(figsize=(10,5))
df["cases"].diff().plot(figsize=(12,5))

# %% [markdown]
# How about california? Riverside?

# %% [markdown]
# ## stocks
#
# - filename: dow jones: data-EKHTG.csv
# - filename: nasdaq: data-APZBu.csv
#
# - source:
# https://www.marketplace.org/2020/05/01/how-the-markets-are-reacting-to-covid-19/

# %%
data=pd.read_csv('../sample-code/data/data-EKHTG.csv',index_col=['Date'])
data.head(10)
# Out:
#               Close
# Date
# 5/2/2020   23749.76
# 5/1/2020   23723.69
# 4/30/2020  24345.72
# 4/29/2020  24633.86
# 4/28/2020  24101.55
# 4/27/2020  24133.78
# 4/24/2020  23775.27
# 4/23/2020  23515.26
# 4/22/2020  23475.82
# 4/21/2020  23018.88

# %%
import matplotlib.pyplot as plt
data.plot(title='dow jones', figsize=(10,5))
plt.gca().invert_xaxis()
#plt.show()

# %%
data=pd.read_csv('../sample-code/data/data-APZBu.csv',index_col=['Date'])
data.plot(title='nasdaq', figsize=(10,5))
plt.gca().invert_xaxis()

# %% [markdown]
# ### Yahoo Finance

# %%
# %pip install pandas_datareader
# Out:
# Collecting pandas_datareader
#   Downloading https://files.pythonhosted.org/packages/22/f1/a02eea03628865c3d4c29849cda8c8a73f43358048aee47d79dfbfa6c6c3/pandas_datareader-0.9.0-py3-none-any.whl (107kB)
# Requirement already satisfied: requests>=2.19.0 in c:\software\anaconda\lib\site-packages (from pandas_datareader) (2.22.0)
# Requirement already satisfied: lxml in c:\software\anaconda\lib\site-packages (from pandas_datareader) (4.4.1)
# Requirement already satisfied: pandas>=0.23 in c:\software\anaconda\lib\site-packages (from pandas_datareader) (0.25.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\software\anaconda\lib\site-packages (from requests>=2.19.0->pandas_datareader) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\software\anaconda\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\software\anaconda\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2019.9.11)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\software\anaconda\lib\site-packages (from requests>=2.19.0->pandas_datareader) (1.24.2)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\software\anaconda\lib\site-packages (from pandas>=0.23->pandas_datareader) (2.8.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\software\anaconda\lib\site-packages (from pandas>=0.23->pandas_datareader) (1.16.5)
# Requirement already satisfied: pytz>=2017.2 in c:\software\anaconda\lib\site-packages (from pandas>=0.23->pandas_datareader) (2019.3)
# Requirement already satisfied: six>=1.5 in c:\software\anaconda\lib\site-packages (from python-dateutil>=2.6.1->pandas>=0.23->pandas_datareader) (1.12.0)
# Installing collected packages: pandas-datareader
# Successfully installed pandas-datareader-0.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# pip install pandas_datareader
# conda install pandas_datareader
#from pandas.util.testing import assert_frame_equal
import pandas_datareader as pdr

# %%
alibaba = pdr.get_data_yahoo("BABA")
#alibaba.head()
msft = pdr.get_data_yahoo("MSFT")
#msft.head()
zoom = pdr.get_data_yahoo("ZM")

# %%
print(alibaba.head())
alibaba.plot(title="alibaba", y = "Close")
plt.xlim('2020-01-01','2020-07-01')
msft.plot(title="MSFT", y = 'Close')
plt.xlim('2020-01-01','2020-07-01')
zoom.plot(title="ZOOM",y='Close')
plt.xlim('2020-01-01','2020-07-01')
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2015-07-27  81.699997  79.680000  80.849998  81.400002  12185700  81.400002
# 2015-07-28  80.800003  79.250000  80.669998  80.559998  12122800  80.559998
# 2015-07-29  81.369003  80.010002  80.980003  80.260002   7177100  80.260002
# 2015-07-30  80.639999  79.449997  80.110001  79.959999   6934700  79.959999
# 2015-07-31  79.904999  78.199997  79.849998  78.339996  12687000  78.339996
# (737425.0, 737607.0)
