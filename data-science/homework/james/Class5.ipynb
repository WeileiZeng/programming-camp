# %%
import pandas as pd
df=pd.read_csv('programming-camp-master/data-science/sample-code/data/us.csv',index_col=['date'])
print(df.head())
# Out:
#             cases  deaths
# date
# 2020-01-21      1       0
# 2020-01-22      1       0
# 2020-01-23      1       0
# 2020-01-24      2       0
# 2020-01-25      3       0

# %%
df.plot()

# %%
#fig1, ax1 = plt.subplots(figsize=(10,5))
df["cases"].diff().plot(figsize=(12,5))

# %%
data=pd.read_csv('programming-camp-master/data-science/sample-code/data/data-EKHTG.csv',index_col=['Date'])
data.head()
# Out:
#               Close
# Date
# 5/2/2020   23749.76
# 5/1/2020   23723.69
# 4/30/2020  24345.72
# 4/29/2020  24633.86
# 4/28/2020  24101.55

# %%
import matplotlib.pyplot as plt
data.plot(title='dow jones', figsize=(10,5))
plt.gca().invert_xaxis()
#plt.show()
#plt.tick_params(axis='both', which='major', labelsize=5,)

# %%
# %pip install pandas_datareader
# Out:
# The following command must be run outside of the IPython shell:
#
#     $ pip install pandas_datareader
#
# The Python package manager (pip) can only be used from outside of IPython.
# Please reissue the `pip` command in a separate terminal or command prompt.
#
# See the Python documentation for more information on how to install packages:
#
#     https://docs.python.org/3/installing/

# %%
# pip install pandas_datareader
# conda install pandas_datareader
#from pandas.util.testing import assert_frame_equal
import pandas_datareader as pdr
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-49a8e505339f> in <module>()
#       2 # conda install pandas_datareader
#       3 #from pandas.util.testing import assert_frame_equal
# ----> 4 import pandas_datareader as pdr
#
# ModuleNotFoundError: No module named 'pandas_datareader'

# %%
alibaba = pdr.get_data_yahoo("BABA")
#alibaba.head()
msft = pdr.get_data_yahoo("MSFT")
#msft.head()
zoom = pdr.get_data_yahoo("ZM")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-0d4c7d1b91a8> in <module>()
# ----> 1 alibaba = pdr.get_data_yahoo("BABA")
#       2 #alibaba.head()
#       3 msft = pdr.get_data_yahoo("MSFT")
#       4 #msft.head()
#       5 zoom = pdr.get_data_yahoo("ZM")
#
# NameError: name 'pdr' is not defined

# %%
print(alibaba.head())
alibaba.plot(title="alibaba", y = "Close")
plt.xlim('2020-01-01','2020-07-01')
msft.plot(title="MSFT", y = 'Close')
plt.xlim('2020-01-01','2020-07-01')
zoom.plot(title="ZOOM",y='Close')
plt.xlim('2020-01-01','2020-07-01')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-d851e8a8008e> in <module>()
# ----> 1 print(alibaba.head())
#       2 alibaba.plot(title="alibaba", y = "Close")
#       3 plt.xlim('2020-01-01','2020-07-01')
#       4 msft.plot(title="MSFT", y = 'Close')
#       5 plt.xlim('2020-01-01','2020-07-01')
#
# NameError: name 'alibaba' is not defined
