# %%
import pandas_datareader as pdr
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
alibaba = pdr.get_data_yahoo("BABA")
#alibaba.head()
msft = pdr.get_data_yahoo("MSFT")
#msft.head()
zoom = pdr.get_data_yahoo("ZM")

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,5))
plt.plot(alibaba[alibaba.index>'2020-01-01']['Close'], label='alibaba Close')
plt.plot(msft[msft.index>'2020-01-01']['Close'], label='microsoft Close')
plt.plot(zoom[zoom.index>'2020-01-01']['Close'], label='microsoft Close')
plt.legend()

# %%
high_tech_names = ['facebook','google','tesla','microsoft','twitter']
high_tech_names_codes = ['FB','GOOG','TSLA','MSFT','TWTR']
high_tech_data = []

# %%
for x in range(5):
  high_tech_data.append(pdr.get_data_yahoo(high_tech_names_codes[x]))

# %%
plt.figure(figsize=(12,5))
for x in range(5):
  plt.plot(high_tech_data[x][high_tech_data[x].index>'2020-01-01']['Close'], label = high_tech_names[x] + ' Close')
plt.legend()

# %% [markdown]
# facebook and google are similar

# %%
# import as needed
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2bf62431-4653-4dd7-8e46-468e28967149" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2bf62431-4653-4dd7-8e46-468e28967149">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2020-05-03_top1000terms.csv to 2020-05-03_top1000terms (2).csv

# %%
# read a file and show detail
#tw = pd.read_csv('DataScience/covid-term/2020-07-06_top1000bigrams.csv')
tw = pd.read_csv('2020-05-03_top1000terms.csv', header=None,names=['term','frequency'])
print(tw.head(50))

#get entry for ketword 'covid'
a=tw[tw['term']=='covid']
print('a=\n',a)
b=a.set_index(pd.Index(range(a.shape[0])))  #reset the index
b.loc[0,'freqency']
print('b=\n',b)
# Out:
#                term  frequency
# 0       coronavirus     328383
# 1             covid     203800
# 2                19     193076
# 3           covid19     167520
# 4               NaN      62057
# 5            people      46485
# 6               amp      44220
# 7             cases      39189
# 8               new      38259
# 9               via      35970
# 10            trump      35641
# 11               us      35339
# 12         pandemic      32337
# 13           deaths      30309
# 14            virus      28311
# 15            china      25257
# 16             news      24841
# 17         lockdown      24658
# 18             like      23712
# 19              one      21695
# 20              000      21681
# 21              get      21323
# 22              may      20165
# 23            world      19933
# 24  realdonaldtrump      19843
# 25             time      18864
# 26            death      18346
# 27             2020      17171
# 28           health      17121
# 29             know      17103
# 30               di      16969
# 31            would      16925
# 32               si      16414
# 33            casos      15599
# 34           crisis      15577
# 35             need      15196
# 36            could      14889
# 37             says      14623
# 38             home      14502
# 39              day      14325
# 40             help      14205
# 41            state      14200
# 42               il      14165
# 43       government      14021
# 44               go      13884
# 45               et      13746
# 46               da      13597
# 47            total      13222
# 48              see      13084
# 49             test      12893
# a=
#         term  frequency
# 1     covid     203800
# 1002  covid     203800
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'freqency'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-5c1d6dc3b8b4> in <module>()
#       8 print('a=\n',a)
#       9 b=a.set_index(pd.Index(range(a.shape[0])))  #reset the index
# ---> 10 b.loc[0,'freqency']
#      11 print('b=\n',b)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1270     def _getitem_tuple(self, tup: Tuple):
#    1271         try:
# -> 1272             return self._getitem_lowerdim(tup)
#    1273         except IndexingError:
#    1274             pass
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#    1419                     return section
#    1420                 # This is an elided recursive call to iloc/loc/etc'
# -> 1421                 return getattr(section, self.name)[new_key]
#    1422
#    1423         raise IndexingError("not applicable")
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1963         # fall thru to straight lookup
#    1964         self._validate_key(key, axis)
# -> 1965         return self._get_label(key, axis=axis)
#    1966
#    1967
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     619             # but will fail when the index is not present
#     620             # see GH5667
# --> 621             return self.obj._xs(label, axis=axis)
#     622         elif isinstance(label, tuple) and isinstance(label[axis], slice):
#     623             raise IndexingError("no slices here, handle elsewhere")
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3535             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3536         else:
# -> 3537             loc = self.index.get_loc(key)
#    3538
#    3539             if isinstance(loc, np.ndarray):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'freqency'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import os
os.system('ls /content/drive/')
print(os.system('ls /content/drive/'))
# Out:
# 0

# %%
# read all files and plot some information
t_range=pd.date_range('2020-03-22','2020-06-25')
#t_range
keywords=['covid']
#keywords=['covid','coronavirus','trump','google','china','wuhan','virus']
#keywords=['trump','google','china','wuhan','virus','doctor','cuomo']

df = DataFrame(index=t_range)             #a DataFrame to save selected data
folder=''  #folder with the data files

#loop through each day
for d in t_range:
    filename=folder + str(d)[:10] + '_top1000terms.csv'
    print('filename --> ',filename)
    tw = pd.read_csv(filename, header=None, names=['term','frequency'])
    
    for key in keywords:
        tw_short=tw[tw['term']==key]
        if tw_short.shape[0]==0:   #check if the key exists or not
            f=0
        else:                      #sometimes there are two duplicates for the entry, not sure why
            tw_short2=tw_short.set_index(pd.Index(range(tw_short.shape[0])))        
            f=tw_short2.loc[0,'frequency']
        df.loc[d,key]=f
# Out:
# filename -->  2020-03-22_top1000terms.csv
# filename -->  2020-03-23_top1000terms.csv
# filename -->  2020-03-24_top1000terms.csv
# filename -->  2020-03-25_top1000terms.csv
# filename -->  2020-03-26_top1000terms.csv
# filename -->  2020-03-27_top1000terms.csv
# filename -->  2020-03-28_top1000terms.csv
# filename -->  2020-03-29_top1000terms.csv
# filename -->  2020-03-30_top1000terms.csv
# filename -->  2020-03-31_top1000terms.csv
# filename -->  2020-04-01_top1000terms.csv
# filename -->  2020-04-02_top1000terms.csv
# filename -->  2020-04-03_top1000terms.csv
# filename -->  2020-04-04_top1000terms.csv
# filename -->  2020-04-05_top1000terms.csv
# filename -->  2020-04-06_top1000terms.csv
# filename -->  2020-04-07_top1000terms.csv
# filename -->  2020-04-08_top1000terms.csv
# filename -->  2020-04-09_top1000terms.csv
# filename -->  2020-04-10_top1000terms.csv
# filename -->  2020-04-11_top1000terms.csv
# filename -->  2020-04-12_top1000terms.csv
# filename -->  2020-04-13_top1000terms.csv
# filename -->  2020-04-14_top1000terms.csv
# filename -->  2020-04-15_top1000terms.csv
# filename -->  2020-04-16_top1000terms.csv
# filename -->  2020-04-17_top1000terms.csv
# filename -->  2020-04-18_top1000terms.csv
# filename -->  2020-04-19_top1000terms.csv
# filename -->  2020-04-20_top1000terms.csv
# filename -->  2020-04-21_top1000terms.csv
# filename -->  2020-04-22_top1000terms.csv
# filename -->  2020-04-23_top1000terms.csv
# filename -->  2020-04-24_top1000terms.csv
# filename -->  2020-04-25_top1000terms.csv
# filename -->  2020-04-26_top1000terms.csv
# filename -->  2020-04-27_top1000terms.csv
# filename -->  2020-04-28_top1000terms.csv
# filename -->  2020-04-29_top1000terms.csv
# filename -->  2020-04-30_top1000terms.csv
# filename -->  2020-05-01_top1000terms.csv
# filename -->  2020-05-02_top1000terms.csv
# filename -->  2020-05-03_top1000terms.csv
# filename -->  2020-05-04_top1000terms.csv
# filename -->  2020-05-05_top1000terms.csv
# filename -->  2020-05-06_top1000terms.csv
# filename -->  2020-05-07_top1000terms.csv
# filename -->  2020-05-08_top1000terms.csv
# filename -->  2020-05-09_top1000terms.csv
# filename -->  2020-05-10_top1000terms.csv
# filename -->  2020-05-11_top1000terms.csv
# filename -->  2020-05-12_top1000terms.csv
# filename -->  2020-05-13_top1000terms.csv
# filename -->  2020-05-14_top1000terms.csv
# filename -->  2020-05-15_top1000terms.csv
# filename -->  2020-05-16_top1000terms.csv
# filename -->  2020-05-17_top1000terms.csv
# filename -->  2020-05-18_top1000terms.csv
# filename -->  2020-05-19_top1000terms.csv
# filename -->  2020-05-20_top1000terms.csv
# filename -->  2020-05-21_top1000terms.csv
# filename -->  2020-05-22_top1000terms.csv
# filename -->  2020-05-23_top1000terms.csv
# filename -->  2020-05-24_top1000terms.csv
# filename -->  2020-05-25_top1000terms.csv
# filename -->  2020-05-26_top1000terms.csv
# filename -->  2020-05-27_top1000terms.csv
# filename -->  2020-05-28_top1000terms.csv
# filename -->  2020-05-29_top1000terms.csv
# filename -->  2020-05-30_top1000terms.csv
# filename -->  2020-05-31_top1000terms.csv
# filename -->  2020-06-01_top1000terms.csv
# filename -->  2020-06-02_top1000terms.csv
# filename -->  2020-06-03_top1000terms.csv
# filename -->  2020-06-04_top1000terms.csv
# filename -->  2020-06-05_top1000terms.csv
# filename -->  2020-06-06_top1000terms.csv
# filename -->  2020-06-07_top1000terms.csv
# filename -->  2020-06-08_top1000terms.csv
# filename -->  2020-06-09_top1000terms.csv
# filename -->  2020-06-10_top1000terms.csv
# filename -->  2020-06-11_top1000terms.csv
# filename -->  2020-06-12_top1000terms.csv
# filename -->  2020-06-13_top1000terms.csv
# filename -->  2020-06-14_top1000terms.csv
# filename -->  2020-06-15_top1000terms.csv
# filename -->  2020-06-16_top1000terms.csv
# filename -->  2020-06-17_top1000terms.csv
# filename -->  2020-06-18_top1000terms.csv
# filename -->  2020-06-19_top1000terms.csv
# filename -->  2020-06-20_top1000terms.csv
# filename -->  2020-06-21_top1000terms.csv
# filename -->  2020-06-22_top1000terms.csv
# filename -->  2020-06-23_top1000terms.csv
# filename -->  2020-06-24_top1000terms.csv
# filename -->  2020-06-25_top1000terms.csv

# %%
df.plot()

# %%
# trying to find the relation between 'covid' tweets and weekends.
# 2020-03-22 is sunday
weekdays=200000
weekends=100000
flag=7
for d in t_range:
    if ( flag <= 5 ):
        #weekdays
        df.loc[d,'week']=weekdays
    else:
        #weekends
        df.loc[d,'week']=weekends
    flag +=1
    if (flag > 6):
        flag = 1
df.plot()
