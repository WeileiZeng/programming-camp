# %% [markdown]
# ## This is the note book for class 6

# %% [markdown]
# https://github.com/WeileiZeng/programming-camp
# https://ucr.zoom.us/j/7738865724

# %%
# covid data
# filename: us.csv
# source: https://github.com/nytimes/covid-19-data

import pandas as pd
df=pd.read_csv('us.csv',index_col=['date'])


print(df.head())
df.plot(figsize=(12,5))
# Out:
#             cases  deaths
# date
# 2020-01-21      1       0
# 2020-01-22      1       0
# 2020-01-23      1       0
# 2020-01-24      2       0
# 2020-01-25      3       0

# %%
df["cases"].diff().plot(figsize=(12,5))

# %%
df["deaths"].diff().plot(figsize=(12,5))

# %%
data=pd.read_csv('data-EKHTG.csv',index_col=['Date'])
data.head(10)
# Out:
#               Close
# Date
# 5/2/2020   23749.76
# 5/1/2020   23723.69
# 4/30/2020  24345.72
# 4/29/2020  24633.86
# 4/28/2020  24101.55
# 4/27/2020  24133.78
# 4/24/2020  23775.27
# 4/23/2020  23515.26
# 4/22/2020  23475.82
# 4/21/2020  23018.88

# %%
import matplotlib.pyplot as plt
data.plot(title='dow jones', figsize=(10,5))
plt.gca().invert_xaxis()
#plt.show()

# %%
data=pd.read_csv('data-APZBu.csv',index_col=['Date'])
data.plot(title='nasdaq', figsize=(10,5))
plt.gca().invert_xaxis()

# %%
data=pd.read_csv('data-APZBu.csv',index_col=['Date'])
data.plot(title='nasdaq', figsize=(10,5))

# %%
data=pd.read_csv('data-ULLTa.csv',index_col=['Date'])
data.plot(title='S&P', figsize=(10,5))
plt.gca().invert_xaxis()
