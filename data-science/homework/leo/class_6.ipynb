# %%
# %pip install pandas_datareader
import matplotlib.pyplot as plt
# pip install pandas_datareader
# conda install pandas_datareader
#from pandas.util.testing import assert_frame_equal
import pandas_datareader as pdr

alibaba = pdr.get_data_yahoo("BABA")
#alibaba.head()
alibaba.plot(title="alibaba", y = "Close")
plt.xlim('2020-01-01','2020-07-01')
# Out:
# Requirement already satisfied: pandas_datareader in c:\users\leoyy\anaconda3\lib\site-packages (0.9.0)
# Requirement already satisfied: pandas>=0.23 in c:\users\leoyy\anaconda3\lib\site-packages (from pandas_datareader) (1.0.1)
# Requirement already satisfied: lxml in c:\users\leoyy\anaconda3\lib\site-packages (from pandas_datareader) (4.5.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\leoyy\anaconda3\lib\site-packages (from pandas_datareader) (2.22.0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\leoyy\anaconda3\lib\site-packages (from pandas>=0.23->pandas_datareader) (2019.3)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\leoyy\anaconda3\lib\site-packages (from pandas>=0.23->pandas_datareader) (1.18.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\leoyy\anaconda3\lib\site-packages (from pandas>=0.23->pandas_datareader) (2.8.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\leoyy\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\leoyy\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\leoyy\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2019.11.28)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\leoyy\anaconda3\lib\site-packages (from requests>=2.19.0->pandas_datareader) (1.25.8)
# Requirement already satisfied: six>=1.5 in c:\users\leoyy\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas>=0.23->pandas_datareader) (1.14.0)
# Note: you may need to restart the kernel to use updated packages.
# (737425.0, 737607.0)

# %%
msft = pdr.get_data_yahoo("MSFT")

msft.plot(title="MSFT", y = 'Close')
plt.xlim('2020-01-01','2020-07-01')
# Out:
# (737425.0, 737607.0)

# %%
zoom = pdr.get_data_yahoo("ZM")
zoom.plot(title="ZOOM",y='Close')
plt.xlim('2020-01-01','2020-07-01')
# Out:
# (737425.0, 737607.0)

# %%
costco = pdr.get_data_yahoo("COST")
costco.plot(title="costco", y = 'Close')
plt.xlim('2020-01-01', '2020-07-01')
# Out:
# (737425.0, 737607.0)

# %%
google = pdr.get_data_yahoo("GOOG")
google.plot(title="google", y = 'Close')
plt.xlim('2020-01-01', '2020-07-01')
# Out:
# (737425.0, 737607.0)
