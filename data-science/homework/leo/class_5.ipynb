# %%
import matplotlib.pyplot as plt
weight = [45.8,47.6,52.1,53.5,54.4,56.7,57.1,58.0]
height = [156.7,158.7, 159.7,162.5,162.5,163,163,163.3]

plt.plot(height,weight)
plt.title("weight versus height for teenage girls, 13-20 years")
plt.xlabel("height (cm)")
plt.ylabel("weight (kg)")

import numpy as np
h = np.arange(157., 163., .1)
w = 1.9 * h - 270 + 17
plt.plot(h, w, 'r--')

# %%
plt.plot(height,weight)
plt.title("weight versus height for teenage girls, 13-20 years")
plt.xlabel("height (cm)")
plt.ylabel("weight (kg)")
# plot a function
import numpy as np
h = np.arange(157., 163., .1)
w = 1.8 * h - 237
# red dashes, blue squares and green triangles
plt.plot(h, w, 'r--')

# %%
import pandas as pd
# date range
#t_range=pd.date_range('2016-01-01','2016-12-31',freq='W')
t_range=pd.date_range('2020-07-01','2020-7-3', freq='H')
t_range
t_range[1]
s= Series(t, index=t_range)
print(s.head())
s.plot()
# Out:
# 2020-07-01 00:00:00    77
# 2020-07-01 01:00:00    76
# 2020-07-01 02:00:00    75
# 2020-07-01 03:00:00    75
# 2020-07-01 04:00:00    73
# Freq: H, dtype: int64

# %%
from pandas import Series

#temperature=list(np.random.randint(low=70,high=90,size=48))
temperature = [77, 76, 75, 75, 73, 72, 73, 75, 77, 77, 79, 80, 
     79, 85, 88, 90, 92, 91, 88, 86, 88, 84, 84, 84, 
     82, 81, 79, 76, 75, 77, 78, 77, 81, 83, 85, 90, 
     93, 99, 96, 97, 99, 98, 95, 94, 92, 92, 85, 84, 83]
#np.random.rand
t=temperature
s = Series(t)
print(s.head())
s.plot()
#print(t)
# Out:
# 0    77
# 1    76
# 2    75
# 3    75
# 4    73
# dtype: int64

# %%
import pandas as pd
df=pd.read_csv('us.csv',index_col=['date'])
df["cases"].diff().plot(title="cases of coivd",figsize=(12,5))

# %%
df["deaths"].diff().plot(title="deaths of covid", figsize=(12,5))

# %%
data=pd.read_csv('data-EKHTG.csv',index_col=['Date'])
data.head()
data.plot(title="stocks",figsize=(12,5))
plt.gca().invert_xaxis()

# %%
data=pd.read_csv('data-APZBu.csv',index_col=['Date'])
data.head()
data.plot(title="stocks#2",figsize=(12,5))
plt.gca().invert_xaxis()
