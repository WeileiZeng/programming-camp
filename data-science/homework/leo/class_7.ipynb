# %%
import pandas_datareader as pdr
import matplotlib.pyplot as plt
retail_names=['costco','amazon','walmart']
retail_codes=['COST','AMZN','WMT']

high_tech_names = ['facebook','google','tesla','microsoft','twitter']
high_tech_codes = ['FB','GOOG','TSLA','MSFT','TWTR']

# online education
education_names =['zoom','mooc','ted','youtube']
education_codes = ['ZM',]

china_high_tech_names=['alibaba','baidu','tencent']
china_high_tech_codes=['BABA','BIDU','TCEHY']

# sample_names=['alibaba','microsoft','zoom']
# sample_codes=['BABA','MSFT','ZM']

sample_names = china_high_tech_names
sample_codes = china_high_tech_codes

n=len(sample_names)
dfs=[]
for i in range(n):
    print(sample_names[i])
    dfs.append(pdr.get_data_yahoo(sample_codes[i]))

print(dfs[0].head())
plt.figure(figsize=(12,5))
for i in range(n):  
    plt.plot(dfs[i][dfs[i].index>'2020-01-01']['Close'],label=sample_names[i])
#    plt.plot(dfs[i]['Close'])
    #dfs[i].plot(title=sample_names[i],y='Close')
plt.legend()
# Out:
# alibaba
# baidu
# tencent
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2015-07-31  79.904999  78.199997  79.849998  78.339996  12687000  78.339996
# 2015-08-03  78.500000  77.110001  78.199997  77.989998   9277000  77.989998
# 2015-08-04  79.353996  77.800003  78.070000  78.870003   8501200  78.870003
# 2015-08-05  80.419998  79.480003  79.589996  79.820000   7502600  79.820000
# 2015-08-06  80.750000  78.639999  79.849998  78.959999   9297800  78.959999

# %%
high_tech_names = ['facebook','google','tesla','microsoft','twitter']
high_tech_codes = ['FB','GOOG','TSLA','MSFT','TWTR']
sample_names = high_tech_names
sample_codes = high_tech_codes
n=len(sample_names)
dfs=[]
for i in range(n):
    print(sample_names[i])
    dfs.append(pdr.get_data_yahoo(sample_codes[i]))

print(dfs[0].head())
plt.figure(figsize=(12,5))
for i in range(n):  
    plt.plot(dfs[i][dfs[i].index>'2020-01-01']['Close'],label=sample_names[i])
#    plt.plot(dfs[i]['Close'])
    #dfs[i].plot(title=sample_names[i],y='Close')
plt.legend()
# Out:
# facebook
# google
# tesla
# microsoft
# twitter
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2015-07-31  96.330002  93.949997  94.949997  94.010002  46509000  94.010002
# 2015-08-03  95.080002  92.800003  93.529999  94.139999  29343100  94.139999
# 2015-08-04  94.730003  93.330002  93.790001  94.059998  20136000  94.059998
# 2015-08-05  97.089996  95.180000  95.250000  96.440002  29813200  96.440002
# 2015-08-06  98.739998  94.419998  97.180000  95.120003  42271300  95.120003

# %% [markdown]
# There are a lot more uses for google then all the Chinese companies.
